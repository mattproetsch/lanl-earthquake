# %% [markdown]
# # Create and run Earthquake Estimator

# %%
# !nvidia-smi
# Out:
# Tue Jan 22 14:24:06 2019
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 410.79       Driver Version: 410.79       CUDA Version: 10.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:81:00.0 Off |                    0 |
# | N/A   41C    P0    38W / 250W |  15519MiB / 16280MiB |     25%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %%
import tensorflow as tf
import lstm_estimator
import earthquake_input_fn
from importlib import reload
import time
import os
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
EARTHQUAKE_DATA_DIR = '/workspace/persistent-data/earthquake/tfrecords2'

# %%
def reload_tf():
    global lstm_estimator
    global earthquake_input_fn
    for i in range(2):
        import lstm_estimator
        import earthquake_input_fn
        reload(lstm_estimator)
        reload(earthquake_input_fn)
        del lstm_estimator
        del earthquake_input_fn
    import lstm_estimator
    import earthquake_input_fn

# %%
reload_tf()

# %%
def create_estimator_from_params(batch_size, timesteps, n_feats, feature_columns,
                                 lstm_cell_size, learning_rate, dropout_rate=0.5, label_input_column=None, model_dir=None):
    
    params = {
        'batch_size': batch_size,
        'timesteps': timesteps,
        'n_feats': n_feats,
        'feature_columns': feature_columns,
        'lstm_cell_size': lstm_cell_size,
        'learning_rate': learning_rate,
        'dropout_rate': dropout_rate,
        'label_input_column': label_input_column
    }
    if model_dir is None:
        model_dir = '/workspace/persistent-data/models/%s' % (time.strftime('%Y-%m-%d-%H-%M-%S'))
    estim = tf.estimator.Estimator(model_fn=lstm_estimator.lstm_model_fn,
                                   params=params,
                                   model_dir=model_dir)
    return estim

# %%
BATCH_SIZE=64
TIMESTEPS=32
LSTM_CELL_SIZE=[128, 64]
LEARNING_RATE=0.000075

# %%
estimator = create_estimator_from_params(batch_size=BATCH_SIZE,
                                         timesteps=TIMESTEPS,
                                         n_feats=1,
                                         feature_columns=[tf.feature_column.numeric_column(key='acousticdata',
                                                                                           dtype=tf.int64,
                                                                                           shape=(BATCH_SIZE, TIMESTEPS))],
                                         lstm_cell_size=LSTM_CELL_SIZE,
                                         learning_rate=LEARNING_RATE)
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_is_chief': True, '_model_dir': '/workspace/persistent-data/models/2019-01-22-09-41-41', '_task_id': 0, '_experimental_distribute': None, '_global_id_in_cluster': 0, '_num_ps_replicas': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fd08c90c358>, '_tf_random_seed': None, '_evaluation_master': '', '_service': None, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_every_n_hours': 10000, '_keep_checkpoint_max': 5, '_eval_distribute': None, '_protocol': None, '_train_distribute': None, '_save_checkpoints_steps': None, '_num_worker_replicas': 1, '_save_checkpoints_secs': 600, '_master': '', '_log_step_count_steps': 100, '_task_type': 'worker', '_device_fn': None, '_save_summary_steps': 100}

# %%
DISTINCT_BATCHES = 100
STEPS_PER_BATCH = int(4096/TIMESTEPS)
TOTAL_STEPS = DISTINCT_BATCHES * STEPS_PER_BATCH
print('running estimator for %d steps' % TOTAL_STEPS)
estimator.train(input_fn=lambda: earthquake_input_fn.earthquake_input_fn2(EARTHQUAKE_DATA_DIR,
                                                                          BATCH_SIZE,
                                                                          TIMESTEPS,
                                                                          scales=['1e1', '1e0'],
                                                                          traintest='train'),
                steps=TOTAL_STEPS)
# Out:
# running estimator for 12800 steps
# INFO:tensorflow:Calling model_fn.
# FEATURES
# {'acousticdata': <tf.Tensor 'IteratorGetNext:0' shape=(?, ?) dtype=int64>}
# --------------------
# LABELS
# Tensor("IteratorGetNext:1", shape=(?, ?), dtype=float64, device=/device:CPU:0)
# --------------------
# MODE
# train
# --------------------
# PARAMS
# {'batch_size': 64, 'lstm_cell_size': [128, 64], 'n_feats': 1, 'label_input_column': None, 'feature_columns': [_NumericColumn(key='acousticdata', shape=(64, 32), default_value=None, dtype=tf.int64, normalizer_fn=None)], 'learning_rate': 7.5e-05, 'timesteps': 32, 'dropout_rate': 0.5}
# --------------------
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /workspace/persistent-data/models/2019-01-22-09-41-41/model.ckpt-1024
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1024 into /workspace/persistent-data/models/2019-01-22-09-41-41/model.ckpt.
# INFO:tensorflow:loss = 4065.6514848158918, step = 1024
# INFO:tensorflow:global_step/sec: 7.77838
# INFO:tensorflow:loss = 4220.625258902432, step = 1124 (12.859 sec)
# INFO:tensorflow:global_step/sec: 8.87716
# INFO:tensorflow:loss = 3554.73147501153, step = 1224 (11.267 sec)
# INFO:tensorflow:global_step/sec: 8.47343
# INFO:tensorflow:loss = 4346.601447153518, step = 1324 (11.802 sec)
# INFO:tensorflow:global_step/sec: 8.5076
# INFO:tensorflow:loss = 3631.555325996847, step = 1424 (11.752 sec)
# INFO:tensorflow:global_step/sec: 8.23811
# INFO:tensorflow:loss = 3999.1943122536914, step = 1524 (12.141 sec)
# INFO:tensorflow:global_step/sec: 8.34205
# INFO:tensorflow:loss = 3392.5725351211395, step = 1624 (11.988 sec)
# INFO:tensorflow:global_step/sec: 8.44315
# INFO:tensorflow:loss = 4327.372717681877, step = 1724 (11.844 sec)
# INFO:tensorflow:global_step/sec: 8.5256
# INFO:tensorflow:loss = 4014.85434113208, step = 1824 (11.729 sec)
# INFO:tensorflow:global_step/sec: 8.29676
# INFO:tensorflow:loss = 3260.695025196905, step = 1924 (12.053 sec)
# INFO:tensorflow:global_step/sec: 8.91905
# INFO:tensorflow:loss = 4341.57099297489, step = 2024 (11.213 sec)
# INFO:tensorflow:global_step/sec: 8.47645
# INFO:tensorflow:loss = 3877.5052585325443, step = 2124 (11.796 sec)
# INFO:tensorflow:global_step/sec: 8.39383
# INFO:tensorflow:loss = 4113.917941749432, step = 2224 (11.914 sec)
# INFO:tensorflow:global_step/sec: 8.98067
# INFO:tensorflow:loss = 3863.8252879153015, step = 2324 (11.134 sec)
# INFO:tensorflow:global_step/sec: 9.0048
# INFO:tensorflow:loss = 3740.295622566919, step = 2424 (11.106 sec)
# INFO:tensorflow:global_step/sec: 8.60885
# INFO:tensorflow:loss = 3335.096636419244, step = 2524 (11.614 sec)
# INFO:tensorflow:global_step/sec: 8.53016
# INFO:tensorflow:loss = 3343.6559400792203, step = 2624 (11.726 sec)
# INFO:tensorflow:global_step/sec: 8.93716
# INFO:tensorflow:loss = 3230.0087748435644, step = 2724 (11.189 sec)
# INFO:tensorflow:global_step/sec: 8.68465
# INFO:tensorflow:loss = 3844.202146154826, step = 2824 (11.514 sec)
# INFO:tensorflow:global_step/sec: 8.84979
# INFO:tensorflow:loss = 3384.183554025458, step = 2924 (11.300 sec)
# INFO:tensorflow:global_step/sec: 8.65107
# INFO:tensorflow:loss = 3919.332084892195, step = 3024 (11.560 sec)
# INFO:tensorflow:global_step/sec: 8.52484
# INFO:tensorflow:loss = 3553.4528463799916, step = 3124 (11.728 sec)
# INFO:tensorflow:global_step/sec: 8.97629
# INFO:tensorflow:loss = 3628.681992859434, step = 3224 (11.146 sec)
# INFO:tensorflow:global_step/sec: 9.0333
# INFO:tensorflow:loss = 3523.0514548621622, step = 3324 (11.066 sec)
# INFO:tensorflow:global_step/sec: 8.39945
# INFO:tensorflow:loss = 3913.4903742624247, step = 3424 (11.905 sec)
# INFO:tensorflow:global_step/sec: 8.72922
# INFO:tensorflow:loss = 3704.5638016035664, step = 3524 (11.456 sec)
# INFO:tensorflow:global_step/sec: 8.78032
# INFO:tensorflow:loss = 2853.454314348712, step = 3624 (11.387 sec)
# INFO:tensorflow:global_step/sec: 8.83647
# INFO:tensorflow:loss = 3151.7513171446176, step = 3724 (11.319 sec)
# INFO:tensorflow:global_step/sec: 8.55662
# INFO:tensorflow:loss = 2808.0809941177095, step = 3824 (11.686 sec)
# INFO:tensorflow:global_step/sec: 8.90877
# INFO:tensorflow:loss = 2963.486650138039, step = 3924 (11.223 sec)
# INFO:tensorflow:global_step/sec: 8.50094
# INFO:tensorflow:loss = 3709.789061021377, step = 4024 (11.764 sec)
# INFO:tensorflow:global_step/sec: 8.50512
# INFO:tensorflow:loss = 3907.275327849791, step = 4124 (11.759 sec)
# INFO:tensorflow:global_step/sec: 8.71713
# INFO:tensorflow:loss = 3376.292229092361, step = 4224 (11.473 sec)
# INFO:tensorflow:global_step/sec: 8.534
# INFO:tensorflow:loss = 2882.000049719225, step = 4324 (11.715 sec)
# INFO:tensorflow:global_step/sec: 8.98897
# INFO:tensorflow:loss = 3219.438148013647, step = 4424 (11.127 sec)
# INFO:tensorflow:global_step/sec: 9.03701
# INFO:tensorflow:loss = 3389.4862226435653, step = 4524 (11.064 sec)
# INFO:tensorflow:global_step/sec: 8.88738
# INFO:tensorflow:loss = 3453.485027541528, step = 4624 (11.252 sec)
# INFO:tensorflow:global_step/sec: 8.72136
# INFO:tensorflow:loss = 3234.8525286974154, step = 4724 (11.467 sec)
# INFO:tensorflow:global_step/sec: 9.05449
# INFO:tensorflow:loss = 2407.4206571691493, step = 4824 (11.044 sec)
# INFO:tensorflow:global_step/sec: 8.63475
# INFO:tensorflow:loss = 3410.9286967372873, step = 4924 (11.582 sec)
# INFO:tensorflow:global_step/sec: 8.86582
# INFO:tensorflow:loss = 3471.640160792794, step = 5024 (11.279 sec)
# INFO:tensorflow:global_step/sec: 8.71427
# INFO:tensorflow:loss = 3484.650566572983, step = 5124 (11.474 sec)
# INFO:tensorflow:global_step/sec: 8.49318
# INFO:tensorflow:loss = 3058.8976002008367, step = 5224 (11.775 sec)
# INFO:tensorflow:global_step/sec: 8.97194
# INFO:tensorflow:loss = 3179.021769847382, step = 5324 (11.146 sec)
# INFO:tensorflow:global_step/sec: 8.65028
# INFO:tensorflow:loss = 3493.7568186986746, step = 5424 (11.562 sec)
# INFO:tensorflow:global_step/sec: 9.00263
# INFO:tensorflow:loss = 3650.516562709704, step = 5524 (11.107 sec)
# INFO:tensorflow:global_step/sec: 8.32644
# INFO:tensorflow:loss = 2924.139073657009, step = 5624 (12.010 sec)
# INFO:tensorflow:global_step/sec: 8.39147
# INFO:tensorflow:loss = 3928.1933753397175, step = 5724 (11.915 sec)
# INFO:tensorflow:global_step/sec: 8.5722
# INFO:tensorflow:loss = 3626.8717406972855, step = 5824 (11.667 sec)
# INFO:tensorflow:global_step/sec: 8.50647
# INFO:tensorflow:loss = 3599.24395110763, step = 5924 (11.757 sec)
# INFO:tensorflow:global_step/sec: 8.31789
# INFO:tensorflow:loss = 3582.03547837683, step = 6024 (12.022 sec)
# INFO:tensorflow:global_step/sec: 8.86233
# INFO:tensorflow:loss = 3212.2920802298854, step = 6124 (11.284 sec)
# INFO:tensorflow:Saving checkpoints for 6194 into /workspace/persistent-data/models/2019-01-22-09-41-41/model.ckpt.
# INFO:tensorflow:global_step/sec: 8.079
# INFO:tensorflow:loss = 3932.5423344235633, step = 6224 (12.376 sec)
# INFO:tensorflow:global_step/sec: 8.82856
# INFO:tensorflow:loss = 4059.033569417067, step = 6324 (11.329 sec)
# INFO:tensorflow:global_step/sec: 8.77603
# INFO:tensorflow:loss = 2765.6877898942785, step = 6424 (11.396 sec)
# INFO:tensorflow:global_step/sec: 8.60864
# INFO:tensorflow:loss = 2043.920119959662, step = 6524 (11.613 sec)
# INFO:tensorflow:global_step/sec: 9.02829
# INFO:tensorflow:loss = 2202.068926260782, step = 6624 (11.079 sec)
# INFO:tensorflow:global_step/sec: 8.51046
# INFO:tensorflow:loss = 2661.3738136600136, step = 6724 (11.750 sec)
# INFO:tensorflow:global_step/sec: 8.09782
# INFO:tensorflow:loss = 4070.092324716265, step = 6824 (12.350 sec)
# INFO:tensorflow:global_step/sec: 8.35499
# INFO:tensorflow:loss = 4408.5640888195, step = 6924 (11.968 sec)
# INFO:tensorflow:global_step/sec: 8.82893
# INFO:tensorflow:loss = 3976.847453337361, step = 7024 (11.326 sec)
# INFO:tensorflow:global_step/sec: 8.41551
# INFO:tensorflow:loss = 3401.3023451397667, step = 7124 (11.883 sec)
# INFO:tensorflow:global_step/sec: 8.66802
# INFO:tensorflow:loss = 15083.91215366812, step = 7224 (11.536 sec)
# INFO:tensorflow:global_step/sec: 9.12937
# INFO:tensorflow:loss = 3012.375076614175, step = 7324 (10.953 sec)
# INFO:tensorflow:global_step/sec: 9.04724
# INFO:tensorflow:loss = 4835.119906726214, step = 7424 (11.054 sec)
# INFO:tensorflow:global_step/sec: 8.71127
# INFO:tensorflow:loss = 4383.99540550942, step = 7524 (11.479 sec)
# INFO:tensorflow:global_step/sec: 8.49898
# INFO:tensorflow:loss = 2161.813082683897, step = 7624 (11.766 sec)
# INFO:tensorflow:global_step/sec: 8.80002
# INFO:tensorflow:loss = 2981.966503142107, step = 7724 (11.362 sec)
# INFO:tensorflow:global_step/sec: 8.44413
# INFO:tensorflow:loss = 3441.417035179903, step = 7824 (11.842 sec)
# INFO:tensorflow:global_step/sec: 8.48331
# INFO:tensorflow:loss = 3237.686083537928, step = 7924 (11.789 sec)
# INFO:tensorflow:global_step/sec: 8.77842
# INFO:tensorflow:loss = 1922.8601433282204, step = 8024 (11.392 sec)
# INFO:tensorflow:global_step/sec: 8.95287
# INFO:tensorflow:loss = 2796.620467517805, step = 8124 (11.170 sec)
# INFO:tensorflow:global_step/sec: 8.76838
# INFO:tensorflow:loss = 3430.676172306957, step = 8224 (11.405 sec)
# INFO:tensorflow:global_step/sec: 8.94761
# INFO:tensorflow:loss = 4051.20059331435, step = 8324 (11.175 sec)
# INFO:tensorflow:global_step/sec: 8.9885
# INFO:tensorflow:loss = 2766.901387339013, step = 8424 (11.124 sec)
# INFO:tensorflow:global_step/sec: 9.01398
# INFO:tensorflow:loss = 1941.9492844635608, step = 8524 (11.095 sec)
# INFO:tensorflow:global_step/sec: 8.80694
# INFO:tensorflow:loss = 2816.1020422923802, step = 8624 (11.356 sec)
# INFO:tensorflow:global_step/sec: 8.69002
# INFO:tensorflow:loss = 3762.082021758183, step = 8724 (11.508 sec)
# INFO:tensorflow:global_step/sec: 8.5022
# INFO:tensorflow:loss = 2582.039493758757, step = 8824 (11.761 sec)
# INFO:tensorflow:global_step/sec: 8.59364
# INFO:tensorflow:loss = 3447.8964520216987, step = 8924 (11.637 sec)
# INFO:tensorflow:global_step/sec: 8.973
# INFO:tensorflow:loss = 3015.95278026009, step = 9024 (11.142 sec)
# INFO:tensorflow:global_step/sec: 8.53728
# INFO:tensorflow:loss = 3760.658217515823, step = 9124 (11.715 sec)
# INFO:tensorflow:global_step/sec: 8.74223
# INFO:tensorflow:loss = 3780.5846461376605, step = 9224 (11.438 sec)
# INFO:tensorflow:global_step/sec: 8.59689
# INFO:tensorflow:loss = 2982.4248075300447, step = 9324 (11.633 sec)
# INFO:tensorflow:global_step/sec: 8.67975
# INFO:tensorflow:loss = 2224.082782004113, step = 9424 (11.520 sec)
# INFO:tensorflow:global_step/sec: 8.85059
# INFO:tensorflow:loss = 2489.3659629962413, step = 9524 (11.299 sec)
# INFO:tensorflow:global_step/sec: 8.81342
# INFO:tensorflow:loss = 3216.705973430782, step = 9624 (11.347 sec)
# INFO:tensorflow:global_step/sec: 8.62718
# INFO:tensorflow:loss = 2494.5553639484374, step = 9724 (11.591 sec)
# INFO:tensorflow:global_step/sec: 8.47482
# INFO:tensorflow:loss = 2240.9170393389954, step = 9824 (11.800 sec)
# INFO:tensorflow:global_step/sec: 8.83615
# INFO:tensorflow:loss = 2612.6187743732985, step = 9924 (11.317 sec)
# INFO:tensorflow:global_step/sec: 8.8499
# INFO:tensorflow:loss = 2956.6334445697908, step = 10024 (11.299 sec)
# INFO:tensorflow:global_step/sec: 8.81451
# INFO:tensorflow:loss = 2993.886849429798, step = 10124 (11.345 sec)
# INFO:tensorflow:global_step/sec: 9.00776
# INFO:tensorflow:loss = 2091.14584511516, step = 10224 (11.099 sec)
# INFO:tensorflow:global_step/sec: 8.66043
# INFO:tensorflow:loss = 2360.7899603340984, step = 10324 (11.549 sec)
# INFO:tensorflow:global_step/sec: 8.40383
# INFO:tensorflow:loss = 3772.5572400483866, step = 10424 (11.899 sec)
# INFO:tensorflow:global_step/sec: 8.46428
# INFO:tensorflow:loss = 2744.6877668257466, step = 10524 (11.814 sec)
# INFO:tensorflow:global_step/sec: 9.08145
# INFO:tensorflow:loss = 5582.161733678714, step = 10624 (11.011 sec)
# INFO:tensorflow:global_step/sec: 8.61343
# INFO:tensorflow:loss = 3390.224379519789, step = 10724 (11.609 sec)
# INFO:tensorflow:global_step/sec: 8.40793
# INFO:tensorflow:loss = 3457.6999004096056, step = 10824 (11.896 sec)
# INFO:tensorflow:global_step/sec: 8.48464
# INFO:tensorflow:loss = 4232.405037036905, step = 10924 (11.785 sec)
# INFO:tensorflow:global_step/sec: 8.55843
# INFO:tensorflow:loss = 2904.0867520988286, step = 11024 (11.685 sec)
# INFO:tensorflow:global_step/sec: 8.84991
# INFO:tensorflow:loss = 2807.3445042999847, step = 11124 (11.299 sec)
# INFO:tensorflow:global_step/sec: 8.59756
# INFO:tensorflow:loss = 2674.6884131101465, step = 11224 (11.632 sec)
# INFO:tensorflow:global_step/sec: 8.45108
# INFO:tensorflow:loss = 2676.2352472039724, step = 11324 (11.832 sec)
# INFO:tensorflow:Saving checkpoints for 11407 into /workspace/persistent-data/models/2019-01-22-09-41-41/model.ckpt.
# INFO:tensorflow:global_step/sec: 8.34215
# INFO:tensorflow:loss = 3583.810429746734, step = 11424 (11.986 sec)
# INFO:tensorflow:global_step/sec: 8.90392
# INFO:tensorflow:loss = 2709.5429122035694, step = 11524 (11.234 sec)
# INFO:tensorflow:global_step/sec: 8.69662
# INFO:tensorflow:loss = 1566.425716073595, step = 11624 (11.497 sec)
# INFO:tensorflow:global_step/sec: 8.76296
# INFO:tensorflow:loss = 2630.4793822868924, step = 11724 (11.411 sec)
# INFO:tensorflow:global_step/sec: 8.83806
# INFO:tensorflow:loss = 2964.015123850264, step = 11824 (11.317 sec)
# INFO:tensorflow:global_step/sec: 8.78227
# INFO:tensorflow:loss = 3222.3010927235905, step = 11924 (11.387 sec)
# INFO:tensorflow:global_step/sec: 8.61382
# INFO:tensorflow:loss = 2786.2685680589098, step = 12024 (11.609 sec)
# INFO:tensorflow:global_step/sec: 8.45113
# INFO:tensorflow:loss = 1885.8168084226938, step = 12124 (11.836 sec)
# INFO:tensorflow:global_step/sec: 8.63369
# INFO:tensorflow:loss = 3473.3183918264385, step = 12224 (11.583 sec)
# INFO:tensorflow:global_step/sec: 8.51473
# INFO:tensorflow:loss = 2882.0751052241426, step = 12324 (11.740 sec)
# INFO:tensorflow:global_step/sec: 8.49148
# INFO:tensorflow:loss = 4946.21901296396, step = 12424 (11.777 sec)
# INFO:tensorflow:global_step/sec: 8.46056
# INFO:tensorflow:loss = 3141.613731905565, step = 12524 (11.819 sec)
# INFO:tensorflow:global_step/sec: 8.8757
# INFO:tensorflow:loss = 2587.222235377165, step = 12624 (11.267 sec)
# INFO:tensorflow:global_step/sec: 8.55895
# INFO:tensorflow:loss = 3149.3582503711104, step = 12724 (11.684 sec)
# INFO:tensorflow:global_step/sec: 8.46242
# INFO:tensorflow:loss = 13371.949178364468, step = 12824 (11.814 sec)
# INFO:tensorflow:global_step/sec: 9.12642
# INFO:tensorflow:loss = 4165.093439565022, step = 12924 (10.961 sec)
# INFO:tensorflow:global_step/sec: 8.44935
# INFO:tensorflow:loss = 2911.0983603533896, step = 13024 (11.834 sec)
# INFO:tensorflow:global_step/sec: 8.81497
# INFO:tensorflow:loss = 2170.3711076574705, step = 13124 (11.342 sec)
# INFO:tensorflow:global_step/sec: 8.57204
# INFO:tensorflow:loss = 2435.3605873260058, step = 13224 (11.669 sec)
# INFO:tensorflow:global_step/sec: 9.0444
# INFO:tensorflow:loss = 3650.6072354297876, step = 13324 (11.054 sec)
# INFO:tensorflow:global_step/sec: 8.90729
# INFO:tensorflow:loss = 2415.664473432013, step = 13424 (11.228 sec)
# INFO:tensorflow:global_step/sec: 8.8393
# INFO:tensorflow:loss = 1841.1751510606482, step = 13524 (11.314 sec)
# INFO:tensorflow:global_step/sec: 8.7664
# INFO:tensorflow:loss = 2482.29829271081, step = 13624 (11.406 sec)
# INFO:tensorflow:global_step/sec: 8.8118
# INFO:tensorflow:loss = 2696.8504484847654, step = 13724 (11.349 sec)
# INFO:tensorflow:Saving checkpoints for 13824 into /workspace/persistent-data/models/2019-01-22-09-41-41/model.ckpt.
# INFO:tensorflow:Loss for final step: 2121.4913236250623.

# %% [markdown]
# We just completed one full epoch through the training data. Let's see how we're doing.

# %%
PRED_BATCHES = 1
TOTAL_PRED_FILES = PRED_BATCHES * BATCH_SIZE
feats_tensor = earthquake_input_fn.earthquake_input_fn2_prediction(EARTHQUAKE_DATA_DIR,
                                                                   BATCH_SIZE,
                                                                   TIMESTEPS,
                                                                   num_files=TOTAL_PRED_FILES,
                                                                   scales=['1e0', '1e1'],
                                                                   traintest='test')

# %%
N_sub_batches = int(4096/TIMESTEPS)
labels = np.ndarray((TOTAL_PRED_FILES, 4096))
feats = np.ndarray((TOTAL_PRED_FILES, 4096))
with tf.Session() as sess:
    for batchnum in range(PRED_BATCHES):
        for i in range(N_sub_batches):
            f = sess.run(feats_tensor)
            feats[batchnum*BATCH_SIZE:(batchnum+1)*BATCH_SIZE,i*TIMESTEPS:(i+1)*TIMESTEPS] = f['acousticdata']
            labels[batchnum*BATCH_SIZE:(batchnum+1)*BATCH_SIZE,i*TIMESTEPS:(i+1)*TIMESTEPS] = f['tminus']

# %%
reload_tf()
#estimator = create_estimator_from_params(BATCH_SIZE,
#                                         TIMESTEPS,
#                                         1,
#                                         feature_columns=[tf.feature_column.numeric_column(key='acousticdata',
#                                                                                           dtype=tf.int64,
#                                                                                           shape=(BATCH_SIZE, TIMESTEPS))],
#                                         lstm_cell_size=LSTM_CELL_SIZE,
#                                         learning_rate=LEARNING_RATE,
#                                         model_dir='/workspace/persistent-data/models/2019-01-21-21-18-12')
predictions = estimator.predict(lambda: earthquake_input_fn.earthquake_input_fn2_prediction(EARTHQUAKE_DATA_DIR,
                                                                                            BATCH_SIZE,
                                                                                            TIMESTEPS,
                                                                                            num_files=TOTAL_PRED_FILES,
                                                                                            scales=['1e0', '1e1'],
                                                                                            traintest='test'),
                                yield_single_examples=False)

# %%
mae = 0.0
preds = np.ndarray((TOTAL_PRED_FILES, 4096))

for i, p in enumerate(predictions):
    batchidx = int(i / N_sub_batches)
    tsidx = i % N_sub_batches
    
    bs = batchidx * BATCH_SIZE
    ts = tsidx * TIMESTEPS
    preds[bs:bs+BATCH_SIZE,ts:ts+TIMESTEPS] = p['pred']
# Out:
# INFO:tensorflow:Calling model_fn.
# FEATURES
# {'acousticdata': <tf.Tensor 'IteratorGetNext:0' shape=(?, ?) dtype=int64>, 'tminus': <tf.Tensor 'IteratorGetNext:1' shape=(?, ?) dtype=float64>}
# --------------------
# LABELS
# None
# --------------------
# MODE
# infer
# --------------------
# PARAMS
# {'batch_size': 64, 'lstm_cell_size': [128, 64], 'n_feats': 1, 'label_input_column': None, 'feature_columns': [_NumericColumn(key='acousticdata', shape=(64, 32), default_value=None, dtype=tf.int64, normalizer_fn=None)], 'learning_rate': 7.5e-05, 'timesteps': 32, 'dropout_rate': 0.5}
# --------------------
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /workspace/persistent-data/models/2019-01-22-09-41-41/model.ckpt-13824
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.

# %%
mae = np.abs(labels[:,-1] - preds[:,-1]).sum() / BATCH_SIZE
mse = ((labels[:,-1] - preds[:,-1])**2).sum() / BATCH_SIZE

mae_batch = np.abs(labels - preds).sum() / BATCH_SIZE
mse_batch = ((labels - preds)**2).sum() / BATCH_SIZE
    
print('mae: %.5f' % mae)
print('mse: %.5f' % mse)
print('mae batch: %.5f' % mae_batch)
print('mse batch: %.5f' % mse_batch)
# Out:
# mae: 3.61969
# mse: 13.97125
# mae batch: 14997.44515
# mse batch: 59070.61567

# %%
for i in range(10):
    #plt.plot(labels[i,:], feats[i])
    plt.plot(labels[i,:], feats[i,:])
    plt.plot(preds[i,:], feats[i,:])
    plt.show()

# %%
DISTINCT_BATCHES = 1323
STEPS_PER_BATCH = int(4096/TIMESTEPS)
TOTAL_STEPS = DISTINCT_BATCHES * STEPS_PER_BATCH
print('running estimator for %d steps' % TOTAL_STEPS)
estimator.train(input_fn=lambda: earthquake_input_fn.earthquake_input_fn2(EARTHQUAKE_DATA_DIR,
                                                                          BATCH_SIZE,
                                                                          TIMESTEPS,
                                                                          scales=['1e1', '1e0'],
                                                                          traintest='train'),
                steps=TOTAL_STEPS)
# Out:
# running estimator for 169344 steps
# INFO:tensorflow:Calling model_fn.
# FEATURES
# {'acousticdata': <tf.Tensor 'IteratorGetNext:0' shape=(?, ?) dtype=int64>}
# --------------------
# LABELS
# Tensor("IteratorGetNext:1", shape=(?, ?), dtype=float64, device=/device:CPU:0)
# --------------------
# MODE
# train
# --------------------
# PARAMS
# {'batch_size': 64, 'lstm_cell_size': [128, 64], 'n_feats': 1, 'label_input_column': None, 'feature_columns': [_NumericColumn(key='acousticdata', shape=(64, 32), default_value=None, dtype=tf.int64, normalizer_fn=None)], 'learning_rate': 7.5e-05, 'timesteps': 32, 'dropout_rate': 0.5}
# --------------------
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /workspace/persistent-data/models/2019-01-22-09-41-41/model.ckpt-13824
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 13824 into /workspace/persistent-data/models/2019-01-22-09-41-41/model.ckpt.
# INFO:tensorflow:loss = 3876.832660957375, step = 13824
# INFO:tensorflow:global_step/sec: 7.24018
# INFO:tensorflow:loss = 1949.822200982016, step = 13924 (13.817 sec)
# INFO:tensorflow:global_step/sec: 8.30836
# INFO:tensorflow:loss = 2014.2765308041764, step = 14024 (12.036 sec)
# INFO:tensorflow:global_step/sec: 8.29872
# INFO:tensorflow:loss = 2834.462802342865, step = 14124 (12.049 sec)
# INFO:tensorflow:global_step/sec: 8.42225
# INFO:tensorflow:loss = 3270.9523679842796, step = 14224 (11.874 sec)
# INFO:tensorflow:global_step/sec: 8.66161
# INFO:tensorflow:loss = 2208.8433280697473, step = 14324 (11.546 sec)
# INFO:tensorflow:global_step/sec: 8.69175
# INFO:tensorflow:loss = 1897.8400330967434, step = 14424 (11.504 sec)
# INFO:tensorflow:global_step/sec: 9.02805
# INFO:tensorflow:loss = 2595.508727790793, step = 14524 (11.078 sec)
# INFO:tensorflow:global_step/sec: 9.05447
# INFO:tensorflow:loss = 2244.950021864804, step = 14624 (11.044 sec)
# INFO:tensorflow:global_step/sec: 8.77918
# INFO:tensorflow:loss = 2655.91640774365, step = 14724 (11.391 sec)
# INFO:tensorflow:global_step/sec: 8.52473
# INFO:tensorflow:loss = 1356.0871010303997, step = 14824 (11.735 sec)
# INFO:tensorflow:global_step/sec: 8.50919
# INFO:tensorflow:loss = 2632.046967359664, step = 14924 (11.746 sec)
# INFO:tensorflow:global_step/sec: 8.16894
# INFO:tensorflow:loss = 2145.820696226826, step = 15024 (12.242 sec)
# INFO:tensorflow:global_step/sec: 8.27129
# INFO:tensorflow:loss = 2037.3080656602547, step = 15124 (12.090 sec)
# INFO:tensorflow:global_step/sec: 9.32665
# INFO:tensorflow:loss = 1072.4414984703296, step = 15224 (10.720 sec)
# INFO:tensorflow:global_step/sec: 8.64984
# INFO:tensorflow:loss = 1790.7906639233931, step = 15324 (11.563 sec)
# INFO:tensorflow:global_step/sec: 8.77631
# INFO:tensorflow:loss = 2346.952862873114, step = 15424 (11.394 sec)
# INFO:tensorflow:global_step/sec: 8.57264
# INFO:tensorflow:loss = 2423.4592067615717, step = 15524 (11.665 sec)
# INFO:tensorflow:global_step/sec: 8.62934
# INFO:tensorflow:loss = 2534.4853865951645, step = 15624 (11.589 sec)
# INFO:tensorflow:global_step/sec: 8.47733
# INFO:tensorflow:loss = 1267.7982685275852, step = 15724 (11.795 sec)
# INFO:tensorflow:global_step/sec: 8.23652
# INFO:tensorflow:loss = 2954.159968428739, step = 15824 (12.142 sec)
# INFO:tensorflow:global_step/sec: 8.56499
# INFO:tensorflow:loss = 1974.2765172490176, step = 15924 (11.680 sec)
# INFO:tensorflow:global_step/sec: 8.49001
# INFO:tensorflow:loss = 2466.8148819083553, step = 16024 (11.775 sec)
# INFO:tensorflow:global_step/sec: 8.63733
# INFO:tensorflow:loss = 1332.555109179446, step = 16124 (11.577 sec)
# INFO:tensorflow:global_step/sec: 8.61173
# INFO:tensorflow:loss = 1554.3339092611907, step = 16224 (11.612 sec)
# INFO:tensorflow:global_step/sec: 8.47001
# INFO:tensorflow:loss = 3912.8398174059867, step = 16324 (11.811 sec)
# INFO:tensorflow:global_step/sec: 8.6705
# INFO:tensorflow:loss = 8381.973483742247, step = 16424 (11.529 sec)
# INFO:tensorflow:global_step/sec: 8.16934
# INFO:tensorflow:loss = 3379.613952422089, step = 16524 (12.240 sec)
# INFO:tensorflow:global_step/sec: 8.26885
# INFO:tensorflow:loss = 3490.2297534912977, step = 16624 (12.091 sec)
# INFO:tensorflow:global_step/sec: 8.30679
# INFO:tensorflow:loss = 2004.8883477652996, step = 16724 (12.041 sec)
# INFO:tensorflow:global_step/sec: 8.53396
# INFO:tensorflow:loss = 2680.39183755618, step = 16824 (11.718 sec)
# INFO:tensorflow:global_step/sec: 8.59378
# INFO:tensorflow:loss = 2801.227096351041, step = 16924 (11.636 sec)
# INFO:tensorflow:global_step/sec: 8.89419
# INFO:tensorflow:loss = 5121.353773120362, step = 17024 (11.248 sec)
# INFO:tensorflow:global_step/sec: 8.52596
# INFO:tensorflow:loss = 1456.2072728129951, step = 17124 (11.724 sec)
# INFO:tensorflow:global_step/sec: 8.62866
# INFO:tensorflow:loss = 944.5257606491871, step = 17224 (11.589 sec)
# INFO:tensorflow:global_step/sec: 8.67956
# INFO:tensorflow:loss = 2032.5506843526546, step = 17324 (11.521 sec)
# INFO:tensorflow:global_step/sec: 8.63952
# INFO:tensorflow:loss = 4031.377767204497, step = 17424 (11.575 sec)
# INFO:tensorflow:global_step/sec: 8.77373
# INFO:tensorflow:loss = 1670.1437043727974, step = 17524 (11.398 sec)
# INFO:tensorflow:global_step/sec: 8.77949
# INFO:tensorflow:loss = 1472.3729470091482, step = 17624 (11.388 sec)
# INFO:tensorflow:global_step/sec: 8.78601
# INFO:tensorflow:loss = 2713.374512122305, step = 17724 (11.384 sec)
# INFO:tensorflow:global_step/sec: 8.6975
# INFO:tensorflow:loss = 2454.777437716702, step = 17824 (11.498 sec)
# INFO:tensorflow:global_step/sec: 8.64979
# INFO:tensorflow:loss = 4035.811321627394, step = 17924 (11.561 sec)
# INFO:tensorflow:global_step/sec: 9.27597
# INFO:tensorflow:loss = 1493.300657303604, step = 18024 (10.780 sec)
# INFO:tensorflow:global_step/sec: 9.00048
# INFO:tensorflow:loss = 1424.4834519962303, step = 18124 (11.115 sec)
# INFO:tensorflow:global_step/sec: 9.14994
# INFO:tensorflow:loss = 2027.8009604170124, step = 18224 (10.925 sec)
# INFO:tensorflow:global_step/sec: 8.37102
# INFO:tensorflow:loss = 2766.6647138813287, step = 18324 (11.946 sec)
# INFO:tensorflow:global_step/sec: 8.49773
# INFO:tensorflow:loss = 3276.5975240981193, step = 18424 (11.768 sec)
# INFO:tensorflow:global_step/sec: 8.17372
# INFO:tensorflow:loss = 3278.351473323491, step = 18524 (12.234 sec)
# INFO:tensorflow:global_step/sec: 8.51321
# INFO:tensorflow:loss = 1628.7362582252954, step = 18624 (11.747 sec)
# INFO:tensorflow:global_step/sec: 8.46295
# INFO:tensorflow:loss = 2967.589855180957, step = 18724 (11.816 sec)
# INFO:tensorflow:global_step/sec: 8.59715
# INFO:tensorflow:loss = 3964.523650718209, step = 18824 (11.632 sec)
# INFO:tensorflow:global_step/sec: 8.32565
# INFO:tensorflow:loss = 1263.1110800706351, step = 18924 (12.016 sec)
# INFO:tensorflow:Saving checkpoints for 18947 into /workspace/persistent-data/models/2019-01-22-09-41-41/model.ckpt.
# INFO:tensorflow:global_step/sec: 8.10685
# INFO:tensorflow:loss = 1758.6903040331902, step = 19024 (12.331 sec)
# INFO:tensorflow:global_step/sec: 8.58479
# INFO:tensorflow:loss = 2177.70549390448, step = 19124 (11.652 sec)
# INFO:tensorflow:global_step/sec: 8.30044
# INFO:tensorflow:loss = 2388.1715822750625, step = 19224 (12.046 sec)
# INFO:tensorflow:global_step/sec: 8.61023
# INFO:tensorflow:loss = 1125.8149910816162, step = 19324 (11.611 sec)
# INFO:tensorflow:global_step/sec: 8.62367
# INFO:tensorflow:loss = 1411.1656226758193, step = 19424 (11.593 sec)
# INFO:tensorflow:global_step/sec: 8.39805
# INFO:tensorflow:loss = 5703.708735759957, step = 19524 (11.910 sec)
# INFO:tensorflow:global_step/sec: 8.12265
# INFO:tensorflow:loss = 1888.4640016973317, step = 19624 (12.311 sec)
# INFO:tensorflow:global_step/sec: 8.3773
# INFO:tensorflow:loss = 2212.1107333945492, step = 19724 (11.937 sec)
# INFO:tensorflow:global_step/sec: 8.45406
# INFO:tensorflow:loss = 1571.541081861063, step = 19824 (11.826 sec)
# INFO:tensorflow:global_step/sec: 8.46559
# INFO:tensorflow:loss = 1703.6818821055335, step = 19924 (11.815 sec)
# INFO:tensorflow:global_step/sec: 8.50039
# INFO:tensorflow:loss = 2162.834024801513, step = 20024 (11.765 sec)
# INFO:tensorflow:global_step/sec: 8.36404
# INFO:tensorflow:loss = 2329.273230900363, step = 20124 (11.955 sec)
# INFO:tensorflow:global_step/sec: 8.27456
# INFO:tensorflow:loss = 7142.8552014939105, step = 20224 (12.086 sec)
# INFO:tensorflow:global_step/sec: 8.43279
# INFO:tensorflow:loss = 1337.9383692853323, step = 20324 (11.862 sec)
# INFO:tensorflow:global_step/sec: 8.2978
# INFO:tensorflow:loss = 1317.5529900396566, step = 20424 (12.047 sec)
# INFO:tensorflow:global_step/sec: 8.49989
# INFO:tensorflow:loss = 1613.45221743416, step = 20524 (11.765 sec)
# INFO:tensorflow:global_step/sec: 8.43097
# INFO:tensorflow:loss = 3240.9343345360576, step = 20624 (11.861 sec)
# INFO:tensorflow:global_step/sec: 8.44254
# INFO:tensorflow:loss = 1257.637454271951, step = 20724 (11.843 sec)
# INFO:tensorflow:global_step/sec: 8.24688
# INFO:tensorflow:loss = 1156.9275924976826, step = 20824 (12.128 sec)
# INFO:tensorflow:global_step/sec: 8.45386
# INFO:tensorflow:loss = 1963.3448588739013, step = 20924 (11.830 sec)
# INFO:tensorflow:global_step/sec: 8.6191
# INFO:tensorflow:loss = 1178.2014508178215, step = 21024 (11.601 sec)
# INFO:tensorflow:global_step/sec: 8.85229
# INFO:tensorflow:loss = 3683.478434938649, step = 21124 (11.297 sec)
# INFO:tensorflow:global_step/sec: 8.58228
# INFO:tensorflow:loss = 1129.5909082361163, step = 21224 (11.652 sec)
# INFO:tensorflow:global_step/sec: 8.37395
# INFO:tensorflow:loss = 1263.1646975707913, step = 21324 (11.942 sec)
# INFO:tensorflow:global_step/sec: 8.68759
# INFO:tensorflow:loss = 3329.6445116512227, step = 21424 (11.515 sec)
# INFO:tensorflow:global_step/sec: 8.56713
# INFO:tensorflow:loss = 2484.215305682551, step = 21524 (11.668 sec)
# INFO:tensorflow:global_step/sec: 8.57833
# INFO:tensorflow:loss = 1097.8758966301984, step = 21624 (11.657 sec)
# INFO:tensorflow:global_step/sec: 8.61505
# INFO:tensorflow:loss = 1069.7534155969379, step = 21724 (11.608 sec)
# INFO:tensorflow:global_step/sec: 8.47058
# INFO:tensorflow:loss = 1476.6984267886437, step = 21824 (11.805 sec)
# INFO:tensorflow:global_step/sec: 8.47427
# INFO:tensorflow:loss = 1919.1967076460369, step = 21924 (11.801 sec)
# INFO:tensorflow:global_step/sec: 8.88916
# INFO:tensorflow:loss = 2996.092942619286, step = 22024 (11.249 sec)
# INFO:tensorflow:global_step/sec: 9.01144
# INFO:tensorflow:loss = 1020.6624211309146, step = 22124 (11.097 sec)
# INFO:tensorflow:global_step/sec: 8.68998
# INFO:tensorflow:loss = 16196.886887354316, step = 22224 (11.505 sec)
# INFO:tensorflow:global_step/sec: 8.37651
# INFO:tensorflow:loss = 1322.3770908831216, step = 22324 (11.940 sec)
# INFO:tensorflow:global_step/sec: 8.20093
# INFO:tensorflow:loss = 2061.576560546366, step = 22424 (12.193 sec)
# INFO:tensorflow:global_step/sec: 8.18047
# INFO:tensorflow:loss = 773.7828867629188, step = 22524 (12.230 sec)
# INFO:tensorflow:global_step/sec: 8.20007
# INFO:tensorflow:loss = 980.4462634532315, step = 22624 (12.192 sec)
# INFO:tensorflow:global_step/sec: 8.75124
# INFO:tensorflow:loss = 1783.98888839661, step = 22724 (11.426 sec)
# INFO:tensorflow:global_step/sec: 8.63817
# INFO:tensorflow:loss = 1974.1506697410516, step = 22824 (11.577 sec)
# INFO:tensorflow:global_step/sec: 8.45405
# INFO:tensorflow:loss = 3651.9554365250037, step = 22924 (11.829 sec)
# INFO:tensorflow:global_step/sec: 8.59593
# INFO:tensorflow:loss = 967.6674975234332, step = 23024 (11.634 sec)
# INFO:tensorflow:global_step/sec: 8.43619
# INFO:tensorflow:loss = 813.648885128314, step = 23124 (11.854 sec)
# INFO:tensorflow:global_step/sec: 8.31165
# INFO:tensorflow:loss = 1520.9213488904088, step = 23224 (12.029 sec)
# INFO:tensorflow:global_step/sec: 8.17131
# INFO:tensorflow:loss = 2492.0478834850537, step = 23324 (12.240 sec)
# INFO:tensorflow:global_step/sec: 8.19936
# INFO:tensorflow:loss = 7818.556375875707, step = 23424 (12.196 sec)
# INFO:tensorflow:global_step/sec: 8.28618
# INFO:tensorflow:loss = 1662.1881276920508, step = 23524 (12.068 sec)
# INFO:tensorflow:global_step/sec: 8.41568
# INFO:tensorflow:loss = 612.0961957750413, step = 23624 (11.888 sec)
# INFO:tensorflow:global_step/sec: 8.29202
# INFO:tensorflow:loss = 1109.226047953923, step = 23724 (12.055 sec)
# INFO:tensorflow:global_step/sec: 8.31358
# INFO:tensorflow:loss = 1516.1438004890633, step = 23824 (12.029 sec)
# INFO:tensorflow:global_step/sec: 8.56598
# INFO:tensorflow:loss = 907.8605812934392, step = 23924 (11.679 sec)
# INFO:tensorflow:Saving checkpoints for 24018 into /workspace/persistent-data/models/2019-01-22-09-41-41/model.ckpt.
# INFO:tensorflow:global_step/sec: 8.00402
# INFO:tensorflow:loss = 880.976902189403, step = 24024 (12.486 sec)
# INFO:tensorflow:global_step/sec: 8.40649
# INFO:tensorflow:loss = 514.7218018097234, step = 24124 (11.899 sec)
# INFO:tensorflow:global_step/sec: 8.6766
# INFO:tensorflow:loss = 2340.6017167332307, step = 24224 (11.524 sec)
# INFO:tensorflow:global_step/sec: 8.88023
# INFO:tensorflow:loss = 4486.318861876034, step = 24324 (11.261 sec)
# INFO:tensorflow:global_step/sec: 8.43287
# INFO:tensorflow:loss = 1029.5185613333986, step = 24424 (11.863 sec)
# INFO:tensorflow:global_step/sec: 8.53623
# INFO:tensorflow:loss = 1519.9894586486184, step = 24524 (11.710 sec)
# INFO:tensorflow:global_step/sec: 8.49541
# INFO:tensorflow:loss = 2094.092908222169, step = 24624 (11.771 sec)
# INFO:tensorflow:global_step/sec: 8.3633
# INFO:tensorflow:loss = 1769.6074798734812, step = 24724 (11.962 sec)
# INFO:tensorflow:global_step/sec: 8.05267
# INFO:tensorflow:loss = 629.2180677385576, step = 24824 (12.418 sec)
# INFO:tensorflow:global_step/sec: 8.56438
# INFO:tensorflow:loss = 947.5553087950715, step = 24924 (11.672 sec)
# INFO:tensorflow:global_step/sec: 8.37099
# INFO:tensorflow:loss = 1376.4989380723978, step = 25024 (11.945 sec)
# INFO:tensorflow:global_step/sec: 8.54087
# INFO:tensorflow:loss = 1575.7396969370263, step = 25124 (11.709 sec)
# INFO:tensorflow:global_step/sec: 8.20618
# INFO:tensorflow:loss = 2227.7332390996653, step = 25224 (12.186 sec)
# INFO:tensorflow:global_step/sec: 8.40819
# INFO:tensorflow:loss = 650.0011210395978, step = 25324 (11.893 sec)
# INFO:tensorflow:global_step/sec: 8.50701
# INFO:tensorflow:loss = 1180.3180085347803, step = 25424 (11.753 sec)
# INFO:tensorflow:global_step/sec: 8.67155
# INFO:tensorflow:loss = 1669.5396098714057, step = 25524 (11.534 sec)
# INFO:tensorflow:global_step/sec: 8.51612
# INFO:tensorflow:loss = 2074.398762384597, step = 25624 (11.743 sec)
